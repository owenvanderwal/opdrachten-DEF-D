# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 5 Invul template

# %% [markdown]
# ## Groep informatie
#
# Aan het einde van deze ontwerpopdracht lever je als groep één gezamenlijk notebook in. Zet jullie studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan.

# %% [markdown]
# | Groep: 42     |  |
# | :-------------|:-------------|
# | Student naan Owen van der Wal| Student Studienummer 6545297 |
# | Student naam Raphaelle Tam| Student Studienummer 6504272 |
# | Student naam Luuk van Dijk| Student Studienummer 6518702 |

# %% [markdown]
# ## Opdracht 1: Planning.

# %% [markdown]
# | Planning Groep: 42     |Tijdstip / Tijdspanne  | Owen van der Wal  |
# |---|---|---|
# | Arduino testen& sanity check arduino | 10:45 - 11:45 | Owen  |
# | ontwerp-eis berekenen| 10:45 - 11:45 | Raphaelle, Luuk |
# | afchecken TA, mogelijk dingen aanpassen niet goed nog | 11:45 - 12:30 | hele groep|
# | middag pauze | 12:30 - 13:30 | hele groep |
# | synthese, schets | 13:30 - 14:30 | hele groep |
# | simulatie, evaluatie en beslissing | 14:30 - 15:00| hele groep |
# | meetplan metingen doen | 15:00 - 15:45  | hele groep|
# | iteratie nodig, zo ja andere metingen | 15:45 - 16:30 | hele groep |
# | leerdoelen, feedback, opruimen, nog alles checken bij TA | 16:30-17:30 | hele groep |

# %% [markdown]
# Run onderstaande cel om alle benodigde libraries te laden. Mogelijk voeg je er zelf nog een aantal toe later vandaag.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
import time
import math

# %% [markdown]
# ## Opdracht 2a: Opsplitsen taak 1: Arduino
# Vul onderstaande tabel in:

# %% [markdown]
# | onderwerp    | antwoord  |
# |---|---|
# | hoe moeilijk (schaal 1 - 10) | 7 |
# | hoe lang voor één meting | 15 minuten |
# | verwacht nauwkeurigheid meting | ±1 Hz  |

# %% [markdown]
# ## Opdracht 2b: Opsplitsen taak 2: afleiding ontwerpeis

# %%
omega = 10 * np.pi * (np.sqrt(2))
kantelfrequentie = 5 * np.sqrt(2)

# %%
def Aout_Ain(omega, f0):
    return 1/(1-((omega)**2/ (2* np.pi * f0)**2) )

x = np.linspace(0, 10, 1000)
y = np.abs(Aout_Ain(2*np.pi*x, 5))
y_test = np.linspace(1/3, 1/3, 1000)

plt.figure()
plt.loglog(x, y)
plt.loglog (x,y_test, 'r--')
plt.xlabel('f0 (Hz)')
plt.ylabel('Aout/Ain')
# Out:
# Text(0, 0.5, 'Aout/Ain')

# %%
# Bereken hier de minimale Delta-x waarbij je aan de eis van de opdracht voldoet.
# Bereken hier de minimale Delta-x waarbij je aan de eis van de opdracht voldoet.
omega0 = 5 * 2 * np.pi
dx = 9.81 / omega0**2
print(dx)
# Out:
# 0.009939608115313336

# %% [markdown]
# ## Opdracht 3: Plot de grafiek.

# %%
m = np.linspace(0.1, 10, 1000)
g = 9.81
def c(m):
    return m*g / dx

def c5(m):
    return np.sqrt(1/5) *m*g / dx

def c3(m):
    return np.sqrt(1/3) * m*g / dx

def c2(m):
    return np.sqrt(1/2) * m*g / dx

plt.figure()
plt.plot(m, c(m), label='c')
plt.plot(m, c5(m), label='c5')
plt.plot(m, c3(m), label='c3')
plt.plot(m, c2(m), label='c2')
plt.xlabel('m (kg)')
plt.ylabel('c (N/m)')  
plt.legend()

# %% [markdown]
# ## Opdracht 4: Verander $\Delta x$.

# %% [markdown]
# We kunnen $\Delta x$ verhogen door:
#
# - vul hier optie 1 in ;door de massa de vergroten
# - vul hier optie 2 in ; door de voorconstante verlagen
#
# Vul onderstaande aan. Geef eventueel met tekst aan waarom je hiervoor gekozen hebt, als extra informatie richting de nakijkers.
#
# Als groep gaan we mikken op een $\Delta x$ van: 5 cm

# %% [markdown]
# ## Opdracht 5: Schets.

# %% [markdown]
# ##### schets opstelling:
# <img src="IMG_5860.jpeg" width="400">

# %% [markdown]
# ## Opdracht 6: Beslissing evaluatie

# %% [markdown]
# Voldoet je ontwerp aan de eisen? Beantwoord de volgende vragen:
#
# ### Wat is de $\Delta x$ van je ontwerp?
#
# **5 cm**
#
# ### Wordt die $\Delta x$ behaald met je gekozen massa en veer?
#
# **ja**
#
# ### hoeveel verder kan je massa-veer systeem nog uitrekken / indrukken?
# Wat is de limiet aan je veer / verend materiaal voordat het niet meer lineair reageert volgens de wet van Hooke?
#
# **Voeg hier je antwoord in**
# 30cm
# ### Is dat genoeg om straks metingen te kunnen doen?
# Hou er rekening mee dat je trillingen een amplitude in de orde grote van een paar centimeter gaan hebben, minder is met deze opzet moeilijk te realiseren.
#
# **Voeg hier je antwoord in**
# Ja
# ### Gaat je ontwerp dus voldoen aan de eis?
#
# **Voeg hier je antwoord in.**
# Ja
# Als je hier positief geantwoord heb, maak dan nog een keer een plot van amplitude overdracht (y-as) versus frequentie (x-as) zoals je hierboven ook al een keer gedaan heb, maar plot nu twee verschillende overdrachten in de grafiek: één die je al had: behorende bij de grens van de ontwerp-eis en één behorende bij je eigen ontwerp. Lees af dat je voor je ontwerp daadwerkelijk onder de eis grafiek zit op de kritieke frequentie!
#
# Deze grafiek heb je later weer nodig om je gemeten punten aan toe te voegen. Ga daarna je massa-veer systeem daadwerkelijk bouwen.
#
# Als je hier negatief geantwoord hebt, kopieer onder deze cel dan alle cellen van Synthese tot en met Evaluation & decision en doorloop dat deel van het ontwerp proces nogmaals.

# %%
# Voeg hier je plot in.
x = np.linspace(0.1, 100, 1000)
y_onze_meting = np.abs(Aout_Ain(2*np.pi*x, 9.81/dx))
plt.figure()
plt.loglog(x, y_onze_meting, label="ons")

# %% [markdown]
# ## Opdracht 7: Plotten maar

# %%
def Aout_Ain(omega, f0):
    return 1/(1-((omega)**2/ (2* np.pi * f0)**2) )
dx= 25 - ((300*9.81) / (4*21.58))
x = np.linspace(0.1, 100, 1000)
y = np.abs(Aout_Ain(2*np.pi*x, 5))
y_onze_meting = np.abs(Aout_Ain(2*np.pi*x, 9.81/dx))


f0 = [2.3,7.4,4.4,5.2,4,3.1,4.6, 17.9,1.6,1.2,0.9]
Aout_Ain_values = [0.1211,0.14/2.52,0.25/0.97,0.08/1.99,0.57/2.67,0.48/5.19,0.45/4.55,0.09/1.96,0.18/0.61, 1.23/0.24,0.12/0.03]

plt.figure()
plt.loglog(x, y)
plt.loglog(x, y_onze_meting, label="ons")
plt.loglog(f0, Aout_Ain_values, 'ro')
plt.errorbar(f0, Aout_Ain_values, yerr=0.04, xerr=0.4,linestyle='', label="onze meting")
plt.xlabel('f0 (Hz)')
plt.ylabel('Aout/Ain')  
plt.legend()
# Out:
# /var/folders/_m/2chzgrf56tv93zlb_z2jyvlc0000gn/T/ipykernel_90632/3924520876.py:2: RuntimeWarning: divide by zero encountered in divide
#   return 1/(1-((omega)**2/ (2* np.pi * f0)**2) )

# %% [markdown]
# ## Opdracht 8: Leerdoelen
# Voeg hieronder zelf kopjes toe om aan te geven wat bij welk leerdoel hoort.

# %% [markdown]
# ## Leerdoel 1
# In het eerste leerdoel moet een grafiek toegevoegd worden waarin wij laten zien dat we instaat zijn om aan de hand van schattingen door middel van berekingen, te bepalen waar onze metingen van het model uiteindelijk theoretisch op uit moeten komen.
#
# - wij hebben dit hieronder gedaan door een grafiek in python te plotten aan de hand van de theoretische formule en de uitgerekend voorconstante van de veren die wij gingen gebruiken in ons model. We hebben ook laten zien dat we aan de hand van omegao de delta x kunnen hebben vastellen met een waarde van 0.0099. Hierbij hebben wij een grafiek geplot met 4 verschillende veerconstanten.

# %%
def Aout_Ain(omega, f0):
    return 1/(1-((omega)**2/ (2* np.pi * f0)**2) )
dx= 25 - ((300*9.81) / (4*21.58))
x = np.linspace(0.1, 100, 1000)
y = np.abs(Aout_Ain(2*np.pi*x, 5))
y_onze_meting = np.abs(Aout_Ain(2*np.pi*x, 9.81/dx))


f0 = [2.3,7.4,4.4,5.2,4,3.1,4.6, 17.9,1.6,1.2,0.9]
Aout_Ain_values = [0.1211,0.14/2.52,0.25/0.97,0.08/1.99,0.57/2.67,0.48/5.19,0.45/4.55,0.09/1.96,0.18/0.61, 1.23/0.24,0.12/0.03]

plt.figure()
#plt.loglog(x, y)
plt.loglog(x, y_onze_meting, label="metingen aan de hand van schatting")
#plt.loglog(f0, Aout_Ain_values, 'ro')
#plt.errorbar(f0, Aout_Ain_values, yerr=0.04, xerr=0.4,linestyle='', label="onze meting")
plt.xlabel('f0 (Hz)')
plt.ylabel('Aout/Ain')  
plt.legend()
# Out:
# /var/folders/_m/2chzgrf56tv93zlb_z2jyvlc0000gn/T/ipykernel_90632/1042551454.py:2: RuntimeWarning: divide by zero encountered in divide
#   return 1/(1-((omega)**2/ (2* np.pi * f0)**2) )

# %%
omega0 = 5 * 2 * np.pi
dx = 9.81 / (omega0**2)
print('de utkomst van delta x',round(dx,4))

m = np.linspace(0.1, 10, 1000)
g = 9.81
def c(m):
    return m*g / dx

def c5(m):
    return np.sqrt(1/5) *m*g / dx

def c3(m):
    return np.sqrt(1/3) * m*g / dx

def c2(m):
    return np.sqrt(1/2) * m*g / dx

plt.figure()
plt.plot(m, c(m), label='c')
plt.plot(m, c5(m), label='c5')
plt.plot(m, c3(m), label='c3')
plt.plot(m, c2(m), label='c2')
plt.xlabel('m (kg)')
plt.ylabel('c (N/m) voor 4 verschillende veerconstantes')  
plt.legend()
# Out:
# de utkomst van delta x 0.0099

# %% [markdown]
# ## leerdoel 2
# In het tweede leerdoel moeten wij kunnen laten zien dat wij in staat zijn om het gemaakte model te kunnen meten. Hierin moeten wij de twee grafieken met onze theoretische waarde en maximale waarde laten zien, waarbij we ook de punten moeten plotten van onze verschillende metingen op verschillende frequenties.
#
# - In de grafiek die wij toegevoegd hebben is de linker grafiek de theoretische grafiek en de rechter grafiek de grafiek met de maximale waardes. Ook hebben wij in de grafiek onze metingen toegevoegd en de punten geplot met de bijbehorende errorbars.

# %%
def Aout_Ain(omega, f0):
    return 1/(1-((omega)**2/ (2* np.pi * f0)**2) )
dx= 25 - ((300*9.81) / (4*21.58))
x = np.linspace(0.1, 100, 1000)
y = np.abs(Aout_Ain(2*np.pi*x, 5))
y_onze_meting = np.abs(Aout_Ain(2*np.pi*x, 9.81/dx))


f0 = [2.3,7.4,4.4,5.2,4,3.1,4.6, 17.9,1.6,1.2,0.9]
Aout_Ain_values = [0.1211,0.14/2.52,0.25/0.97,0.08/1.99,0.57/2.67,0.48/5.19,0.45/4.55,0.09/1.96,0.18/0.61, 1.23/0.24,0.12/0.03]

plt.figure()
plt.loglog(x, y)
plt.loglog(x, y_onze_meting, label="ons")
plt.loglog(f0, Aout_Ain_values, 'ro')
plt.errorbar(f0, Aout_Ain_values, yerr=0.04, xerr=0.4,linestyle='', label="onze meting")
plt.xlabel('f0 (Hz)')
plt.ylabel('Aout/Ain')  
plt.legend()
# Out:
# /var/folders/_m/2chzgrf56tv93zlb_z2jyvlc0000gn/T/ipykernel_90632/4092860303.py:2: RuntimeWarning: divide by zero encountered in divide
#   return 1/(1-((omega)**2/ (2* np.pi * f0)**2) )
